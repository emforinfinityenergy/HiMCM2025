# %% [markdown]
# # Calculating Indicator Scores

# %% [markdown]
# ## Setup

# %%
import numpy as np

city = np.array(["New Orleans", "Inglewood", "Glendale", "Las Vegas", "Santa Clara", "Atlanta", "Cleveland", "Cincinnati", "Buffalo"])

reg = lambda x: (1 - np.tanh(40 * x - 2)) / 2

# %% [markdown]
# ## Data

# %%
baseline = np.array([150000, 2, 450, 16000])

temp = np.array([12.8, 14.5, 30.9, 27.2, 12, 10.5, 1, 1.7, 2.8])
loc = np.array([1.1, 1.8, 1.6, 1.2, 1.5, 0.9, 1.01, 0.66, 6])
trans = np.array([83.7, 80, 77.5, 85, 82.4, 98, 81, 80.3, 78.4])
energy = np.array([43, 68, 44.9, 53.4, 76.9, 62, 68.8, 82.9, 50.7])
landfill = np.array([97, 92, 81, 76, 68, 77, 96, 77.8, 70])
airport = np.array([18.7, 7.5, 32.1, 7, 14.1, 17.5, 20.4, 21.3, 21.1])
res = np.array([149000000, 5940000, 13500000, 356000000, 11000000, 147000000, 513000000, 132000000, 160000000])
neutralization = np.array([74550 / 365, 21000 / 365, 38325 / 365, 124250 / 365, 24850 / 365, 95813 / 365, 270, 680, 140])

# %% [markdown]
# ## Calculation

# %%
# water
alpha = 3.5
water = reg(alpha * temp / temp[0] * baseline[0] / res)
print(list(water))

# waste
beta = 0.2
waste = (beta * temp[2] * landfill / 100 + (1 - beta) * temp[1] * landfill / 100) * -1
print(list(waste))

# gas
gamma = 0.79
sigma = 1.1
epsilon = 1.4
eta = 1.03
emission = reg(gamma * loc / loc[0] * sigma * trans / trans[0] * epsilon * energy / energy[0] * eta * airport / airport[0] / neutralization)
print(gamma * loc / loc[0] * sigma * trans / trans[0] * epsilon * energy / energy[0] * eta * airport / airport[0] / neutralization)
print(list(emission))
# Out:
# [np.float64(0.9762959721488693), np.float64(0.017814186887043837), np.float64(0.029017293827856616), np.float64(0.9770068597723778), np.float64(0.6035920134818468), np.float64(0.9773707999669627), np.float64(0.9819004668617325), np.float64(0.9812519862030169), np.float64(0.9809709880319621)]
# [np.float64(-17.2466), np.float64(-16.357599999999998), np.float64(-14.401800000000001), np.float64(-13.5128), np.float64(-12.0904), np.float64(-13.690600000000002), np.float64(-17.0688), np.float64(-13.832840000000001), np.float64(-12.446000000000002)]
# [0.00613522 0.02160544 0.02880982 0.0018958  0.03331864 0.00617055
#  0.0071981  0.00232939 0.06083962]
# [np.float64(0.9709479065249562), np.float64(0.90649452350998), np.float64(0.8449086418777338), np.float64(0.9791296773793348), np.float64(0.7915855055913192), np.float64(0.9708680861206632), np.float64(0.9684508702410912), np.float64(0.978408954940134), np.float64(0.2958435186389383)]

# %% [markdown]
# ## Concat

# %%
res = []
for i in range(len(water)):
    res.append([water[i], waste[i], emission[i]])

print(res)
# Out:
# [[np.float64(0.9762959721488693), np.float64(-17.2466), np.float64(0.9709479065249562)], [np.float64(0.017814186887043837), np.float64(-16.357599999999998), np.float64(0.90649452350998)], [np.float64(0.029017293827856616), np.float64(-14.401800000000001), np.float64(0.8449086418777338)], [np.float64(0.9770068597723778), np.float64(-13.5128), np.float64(0.9791296773793348)], [np.float64(0.6035920134818468), np.float64(-12.0904), np.float64(0.7915855055913192)], [np.float64(0.9773707999669627), np.float64(-13.690600000000002), np.float64(0.9708680861206632)], [np.float64(0.9819004668617325), np.float64(-17.0688), np.float64(0.9684508702410912)], [np.float64(0.9812519862030169), np.float64(-13.832840000000001), np.float64(0.978408954940134)], [np.float64(0.9809709880319621), np.float64(-12.446000000000002), np.float64(0.2958435186389383)]]
